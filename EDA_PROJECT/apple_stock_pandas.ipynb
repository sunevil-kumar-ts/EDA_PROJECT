# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r"C:\Users\user\Downloads\apple_5yr_one.csv")
print(data.head(4))
# Out:
#          Date              Close               High                Low  \
# 0         NaN               AAPL               AAPL               AAPL
# 1  2020-06-04  78.32931518554688   79.1312690763083  77.95506657558614
# 2  2020-06-05  80.56021881103516  80.62097312386399  78.55046881252456
# 3  2020-06-08  81.03653717041016  81.07056314819836  79.54441498185327
#
#                 Open     Volume
# 0               AAPL       AAPL
# 1  78.83236263047952   87560400
# 2  78.57962969607472  137250400
# 3  80.25645380649277   95654400

# %%
data1 = data.dropna()
print(data1.head(4))
# Out:
#          Date              Close               High                Low  \
# 1  2020-06-04  78.32931518554688   79.1312690763083  77.95506657558614
# 2  2020-06-05  80.56021881103516  80.62097312386399  78.55046881252456
# 3  2020-06-08  81.03653717041016  81.07056314819836  79.54441498185327
# 4  2020-06-09  83.59550476074219  83.98919153470604  80.68416273702039
#
#                 Open     Volume
# 1  78.83236263047952   87560400
# 2  78.57962969607472  137250400
# 3  80.25645380649277   95654400
# 4  80.71575616737768  147712400

# %%
data1.dtypes
# Out:
# Date      datetime64[ns]
# Close             object
# High              object
# Low               object
# Open              object
# Volume            object
# dtype: object

# %%
data1['Date'] = pd.to_datetime(data1['Date'])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11732\3750176488.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['Date'] = pd.to_datetime(data1['Date'])

# %%
data1['Volume'] = data1['Volume'].astype(int)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11732\3284237594.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['Volume'] = data1['Volume'].astype(int)

# %%
data1.dtypes
# Out:
# Date      datetime64[ns]
# Close            float64
# High             float64
# Low              float64
# Open             float64
# Volume             int64
# dtype: object

# %%
#Display rows where Close price > 150 and Volume > 10000000.

# %%
#Find the date where Apple stock had the highest High price.

# %%
#Find the date with the lowest Low price.

# %%
#Display top 10 days with highest trading volume.

# %%
#Write a Python program to calculate the average closing price for each year using groupby().

# %%
#Write a program to calculate the total trading volume for each year.

# %%
#Write a program to calculate the total trading volume for each year.

# %%
#Find the maximum stock price for each year.

# %%
#Find the lowest stock price for each year.

# %%
#Calculate mean, maximum, and minimum closing prices for each year.

# %%
#Calculate the average closing price for each month.

# %%
#Calculate the average closing price for each month.

# %%
#Find the total trading volume for each month.

# %%
#Find the average opening and closing price for each year.
